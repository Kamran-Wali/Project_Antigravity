# %%
#import dependencies
import os 
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
#reading csv for outstanding student loans data
file_1 = "loanportfolio.csv"
outstanding_loans = pd.read_csv(file_1)
outstanding_loans
# Out:
#       Year  Direct Dollars Outstanding  Direct recipients  \
# 0   2007.0                       106.8                7.0
# 1   2008.0                       122.5                7.7
# 2   2009.0                       154.9                9.2
# 3   2010.0                       224.5               14.4
# 4   2011.0                       350.1               19.4
# 5   2012.0                       488.3               22.8
# 6   2013.0                       609.1               25.6
# 7   2014.0                       726.6               27.9
# 8   2015.0                       840.7               29.9
# 9   2016.0                       949.1               31.5
# 10  2017.0                      1053.5               33.0
# 11  2018.0                      1116.0               33.3
#
#     FFEL Dollars Outstanding  FFEL recipients  Perkins Outstanding  \
# 0                      401.9             22.6                  8.2
# 1                      446.5             23.7                  8.5
# 2                      493.3             25.0                  8.7
# 3                      516.7             25.1                  8.4
# 4                      489.8             23.8                  8.3
# 5                      451.7             22.4                  8.2
# 6                      423.0             20.9                  8.1
# 7                      395.0             19.4                  8.2
# 8                      363.6             17.9                  8.1
# 9                      335.2             16.4                  7.9
# 10                     305.8             14.9                  7.6
# 11                     288.6             13.8                  7.4
#
#     Perkins Recipients  Total Dollars Outstanding  \
# 0                  2.8                      516.0
# 1                  2.9                      577.0
# 2                  3.0                      657.0
# 3                  2.9                      749.8
# 4                  2.9                      848.2
# 5                  2.9                      948.2
# 6                  2.9                     1040.2
# 7                  2.9                     1129.8
# 8                  2.8                     1212.4
# 9                  2.7                     1292.2
# 10                 2.5                     1366.9
# 11                 2.4                     1412.0
#
#     Total unduplicated recipients
# 0                            28.3
# 1                            29.9
# 2                            32.1
# 3                            34.3
# 4                            36.5
# 5                            38.3
# 6                            39.6
# 7                            40.7
# 8                            41.6
# 9                            42.3
# 10                           42.6
# 11                           42.2

# %%
#reading csv for student loan growth rate
file_2 = "LoansData.csv"
loans_rate = pd.read_csv(file_2)
loans_rate
# Out:
#        Year  2016 Loans Billions  2018 Loans Billions
# 0   1996/97                 46.5             48.85290
# 1   1997/98                 48.5             50.95410
# 2   1998/99                 50.3             52.84518
# 3   1999/00                 53.8             56.52228
# 4   2000/01                 54.9             57.67794
# 5   2001/02                 59.2             62.19552
# 6   2002/03                 68.3             71.75598
# 7   2003/04                 78.9             82.89234
# 8   2004/05                 87.3             91.71738
# 9   2005/06                 92.3             96.97038
# 10  2006/07                 96.3            101.17278
# 11  2007/08                105.1            110.41806
# 12  2008/09                107.2            112.62432
# 13  2009/10                120.8            126.91248
# 14  2010/11                125.6            131.95536
# 15  2011/12                122.7            128.90862
# 16  2012/13                117.5            123.44550
# 17  2013/14                114.3            120.08358
# 18  2014/15                108.9            114.41034
# 19  2015/16                107.3            112.72938
# 20  2016/17                106.5            111.88890

# %%
#Visualizing data 
plt.figure(figsize = (10,8))
plt.plot(loans_rate["Year"], loans_rate["2018 Loans Billions"], marker = "o")
plt.title("Year vs. Total Student Loans in 2018 dollars(Billions)\n Data Source : College Board")
plt.xlabel("Year")
plt.xticks(rotation=70)
plt.ylabel("Total Student Loans (Billions)")
plt.grid()
plt.savefig("plots/YearvsTotalStudentLoans.png", bbox_inches="tight")

# %%
#plotting total outstanding student loans 
x_axis = outstanding_loans["Year"]
y_axis = outstanding_loans["Total Dollars Outstanding"]
plt.plot(x_axis,y_axis)
plt.title("Year vs. Total Outstanding Student Loans (Billions)")
plt.xlabel("Year")
plt.xticks(rotation=70)
plt.xticks(np.arange(min(x_axis), max(x_axis)+1, 1.0))
plt.ylabel("Total Outstanding Student Loans (Billions)")
plt.grid()
plt.text(2019,1300, "Data Source: \n National Student Loan Data System(NSLDS)")
plt.savefig("plots/YearvsTotalStudentLoansOutstanding.png", bbox_inches="tight")

# %%
#plotting total outstanding student loans 
x_axis = outstanding_loans["Year"]
y_axis = outstanding_loans["Total unduplicated recipients"]
plt.plot(x_axis,y_axis)
plt.title("Year vs. Total Recipients (Millions)")
plt.xlabel("Year")
plt.xticks(rotation=70)
plt.xticks(np.arange(min(x_axis), max(x_axis)+1, 1.0))
plt.ylabel("Total Outstanding Student Loans (Millions)")
plt.grid()
plt.text(2019,42, "Data Source: NSLDS \n 2018 4th quarter data unavailable")
plt.savefig("plots/YearvsTotalRecipients.png", bbox_inches="tight")

# %%
file_3 = "Studentloans_delinquency.csv"
loansdelinquency_rate = pd.read_csv(file_3)
loansdelinquency_rate
# Out:
#     Year  Student Loan Delinquency  Percent Total Debt
# 0   2003                      3.79                 6.23
# 1   2004                      5.64                 6.32
# 2   2005                      6.14                 6.59
# 3   2006                      9.93                 7.14
# 4   2007                     11.11                 7.51
# 5   2008                     12.75                 7.82
# 6   2009                     14.54                 8.66
# 7   2010                     16.18                 9.12
# 8   2011                     20.41                 8.45
# 9   2012                     28.61                11.73
# 10  2013                     26.87                11.51
# 11  2014                     29.48                11.32
# 12  2015                     29.41                11.52
# 13  2016                     30.99                11.17
# 14  2017                     28.86                10.98
# 15  2018                     26.00                10.94

# %%
x_axis = loansdelinquency_rate["Year"]
y_axis = loansdelinquency_rate["Student Loan Delinquency"]
plt.plot(x_axis,y_axis)
plt.title("Year vs. Student Loan Delinquency(Billions$)")
plt.xlabel("Year")
plt.xticks(rotation=70)
plt.xticks(np.arange(min(x_axis), max(x_axis)+1, 1.0))
plt.ylabel("Student loan Delinquency(Billions$)")
plt.grid()
plt.text(2019,32, "Data Source: New York Fed Consumer Credit Panel \n 2018 3rd and 4th quarter data unavailable")
plt.savefig("plots/YearvsTotalRecipients.png", bbox_inches="tight")
plt.savefig("plots/YearvsStudentLoanDelinquincy.png", bbox_inches="tight")
slope, intercept, r_value, p_value, std_err = stats.linregress(x_axis, y_axis)

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(x_axis, y_axis)
print("r-squared:", r_value**2)
print("pvalue:", p_value)
# Out:
# r-squared: 0.8958208678635022
# pvalue: 2.9266692089129814e-08

# %%
x_axis = loansdelinquency_rate["Year"]
y_axis = loansdelinquency_rate["Percent Total Debt "]
plt.plot(x_axis, y_axis)
plt.title("Year vs. Student Loan Delinquency(% Total Debt)")
plt.xlabel("Year")
plt.xticks(rotation=70)
plt.xticks(np.arange(min(x_axis), max(x_axis)+1, 1.0))
plt.ylabel("Student loan Delinquency(% Total Debt)")
plt.grid()
plt.text(2019,11, "Data Source: New York Fed Consumer Credit Panel \n 2018 3rd and 4th quarter data unavailable")
plt.savefig("plots/YearvsPercentDelinquency.png", bbox_inches="tight")
